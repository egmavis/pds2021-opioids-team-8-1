# %%
import pandas as pd
import numpy as np

# %%
#Read in the data
dfl = pd.read_csv('/Users/weilianghu/Downloads/arcos-la-statewide-itemized.csv.gz', compression='gzip')
dfl.head()
# Out:
# /Users/weilianghu/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (3,5,22,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME REPORTER_ADDL_CO_INFO  \
# 0       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 3       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 4       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
#
#         REPORTER_ADDRESS1 REPORTER_ADDRESS2     REPORTER_CITY REPORTER_STATE  \
# 0  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 1  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# ...

# %%
#Subset the data for the corresponding variables that we need
cols = ["BUYER_STATE",
    "BUYER_COUNTY",
    "MME_Conversion_Factor",
    "CALC_BASE_WT_IN_GM",
    "TRANSACTION_DATE"]

dfl1 = dfl[cols]
dfl1
# Out:
#         BUYER_STATE BUYER_COUNTY  MME_Conversion_Factor  CALC_BASE_WT_IN_GM  \
# 0                LA    ASCENSION                    1.5           13.447500
# 1                LA    ASCENSION                    1.5            2.689500
# 2                LA    ASCENSION                    1.5            2.689500
# 3                LA    ASCENSION                    1.5            0.672375
# 4                LA    JEFFERSON                    1.0           18.162000
# ...             ...          ...                    ...                 ...
# 4359844          LA    LAFAYETTE                    1.0           18.162000
# 4359845          LA   TANGIPAHOA                    1.5           13.447500
# 4359846          LA   TANGIPAHOA                    1.5           24.205500
# 4359847          LA   TANGIPAHOA                    1.0            0.454050
# 4359848          LA   TANGIPAHOA                    1.5            5.379000
#
#          TRANSACTION_DATE
# 0                 7062006
# ...

# %%
# Check for missing data
assert not dfl1["BUYER_STATE"].isnull().any()
assert not dfl1["BUYER_COUNTY"].isnull().any()
assert not dfl1["MME_Conversion_Factor"].isnull().any()
assert not dfl1["CALC_BASE_WT_IN_GM"].isnull().any()
assert not dfl1["TRANSACTION_DATE"].isnull().any()

# %%
# Change date variable to year
dfl1["TRANS_TIME"] = pd.to_datetime(dfl1['TRANSACTION_DATE'], format = '%m%d%Y')
dfl1["YEAR"] = pd.DatetimeIndex(dfl1["TRANS_TIME"]).year
dfl1["MONTH"] = pd.DatetimeIndex(dfl1["TRANS_TIME"]).month
dfl1
# Out:
# /var/folders/sv/ch7d2k6s3slbbzb1gm2s7dkr0000gn/T/ipykernel_63468/2084112708.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfl1["TRANS_TIME"] = pd.to_datetime(dfl1['TRANSACTION_DATE'], format = '%m%d%Y')
# /var/folders/sv/ch7d2k6s3slbbzb1gm2s7dkr0000gn/T/ipykernel_63468/2084112708.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfl1["YEAR"] = pd.DatetimeIndex(dfl1["TRANS_TIME"]).year
# ...

# %%
# Group by County and year and calculate opioid quantity.
dfl_by_county = dfl1.groupby(["BUYER_STATE", "BUYER_COUNTY", "YEAR", "MONTH"]).sum().reset_index()
dfl_by_county["MME_monthly"] = dfl_by_county['CALC_BASE_WT_IN_GM'] * 1000 * dfl_by_county["MME_Conversion_Factor"]
dfl_by_county
final_columns = ["BUYER_STATE", "BUYER_COUNTY", "MONTH", "YEAR", "MME_monthly"]
dfl_final = dfl_by_county[final_columns]
dfl_final
# Out:
#      BUYER_STATE BUYER_COUNTY  MONTH  YEAR   MME_monthly
# 0             LA       ACADIA      1  2006  2.720498e+07
# 1             LA       ACADIA      2  2006  6.222370e+08
# 2             LA       ACADIA      3  2006  8.799659e+08
# 3             LA       ACADIA      4  2006  6.576540e+08
# 4             LA       ACADIA      5  2006  8.304159e+08
# ...          ...          ...    ...   ...           ...
# 6829          LA         WINN      8  2014  9.332066e+07
# 6830          LA         WINN      9  2014  8.792937e+07
# 6831          LA         WINN     10  2014  1.304262e+08
# 6832          LA         WINN     11  2014  9.098404e+07
# 6833          LA         WINN     12  2014  1.059810e+08
#
# [6834 rows x 5 columns]

# %%
dfl_final.to_csv("Opioid_LA.csv")
dfl_final.to_parquet("Opioid_LA.gzip", compression="gzip")
