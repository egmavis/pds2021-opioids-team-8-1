# %%
import pandas as pd
import numpy as np

# %%
#Read in the data
dfo = pd.read_csv('/Users/weilianghu/Downloads/arcos-ok-statewide-itemized.csv.gz', compression='gzip')
dfo.head()
# Out:
# /Users/weilianghu/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (3,5,22,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME REPORTER_ADDL_CO_INFO  \
# 0       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 3       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 4       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
#
#         REPORTER_ADDRESS1 REPORTER_ADDRESS2     REPORTER_CITY REPORTER_STATE  \
# 0  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 1  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# ...

# %%
#Subset the data for the corresponding variables that we need
cols = ["BUYER_STATE",
    "BUYER_COUNTY",
    "MME_Conversion_Factor",
    "CALC_BASE_WT_IN_GM",
    "TRANSACTION_DATE"]

dfo1 = dfo[cols]
dfo1
# Out:
#         BUYER_STATE BUYER_COUNTY  MME_Conversion_Factor  CALC_BASE_WT_IN_GM  \
# 0                OK     OKLAHOMA                    1.5            0.479574
# 1                OK        TULSA                    1.0            3.027000
# 2                OK     OKLAHOMA                    1.5            1.793000
# 3                OK     OKLAHOMA                    1.0            0.454050
# 4                OK     OKLAHOMA                    1.0            0.454050
# ...             ...          ...                    ...                 ...
# 4342558          OK     OKLAHOMA                    1.0            6.054000
# 4342559          OK     OKLAHOMA                    1.0            1.513500
# 4342560          OK        CREEK                    1.0           18.162000
# 4342561          OK     COMANCHE                    1.0            0.605400
# 4342562          OK     LE FLORE                    1.0           12.108000
#
#          TRANSACTION_DATE
# 0                 1102006
# ...

# %%
# Check for missing data
assert not dfo1["BUYER_STATE"].isnull().any()
assert not dfo1["BUYER_COUNTY"].isnull().any()
assert not dfo1["MME_Conversion_Factor"].isnull().any()
assert not dfo1["CALC_BASE_WT_IN_GM"].isnull().any()
assert not dfo1["TRANSACTION_DATE"].isnull().any()

# %%
# Change date variable to year
dfo1["TRANS_TIME"] = pd.to_datetime(dfo1['TRANSACTION_DATE'], format = '%m%d%Y')
dfo1["YEAR"] = pd.DatetimeIndex(dfo1["TRANS_TIME"]).year
dfo1["MONTH"] = pd.DatetimeIndex(dfo1["TRANS_TIME"]).month
dfo1
# Out:
# /var/folders/sv/ch7d2k6s3slbbzb1gm2s7dkr0000gn/T/ipykernel_64111/3723647068.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfo1["TRANS_TIME"] = pd.to_datetime(dfo1['TRANSACTION_DATE'], format = '%m%d%Y')
# /var/folders/sv/ch7d2k6s3slbbzb1gm2s7dkr0000gn/T/ipykernel_64111/3723647068.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfo1["YEAR"] = pd.DatetimeIndex(dfo1["TRANS_TIME"]).year
# ...

# %%
# Group by County and year and calculate opioid quantity.
dfo_by_county = dfo1.groupby(["BUYER_STATE", "BUYER_COUNTY", "YEAR", "MONTH"]).sum().reset_index()
dfo_by_county["MME_monthly"] = dfo_by_county['CALC_BASE_WT_IN_GM'] * 1000 * dfo_by_county["MME_Conversion_Factor"]
dfo_by_county
final_columns = ["BUYER_STATE", "BUYER_COUNTY", "MONTH", "YEAR", "MME_monthly"]
dfo_final = dfo_by_county[final_columns]
dfo_final
# Out:
#      BUYER_STATE BUYER_COUNTY  MONTH  YEAR   MME_monthly
# 0             OK        ADAIR      1  2006  1.290610e+06
# 1             OK        ADAIR      2  2006  3.611407e+07
# 2             OK        ADAIR      3  2006  4.456391e+07
# 3             OK        ADAIR      4  2006  4.002866e+07
# 4             OK        ADAIR      5  2006  5.682092e+07
# ...          ...          ...    ...   ...           ...
# 8287          OK     WOODWARD      8  2014  1.232863e+08
# 8288          OK     WOODWARD      9  2014  1.354420e+08
# 8289          OK     WOODWARD     10  2014  2.030496e+08
# 8290          OK     WOODWARD     11  2014  1.644301e+08
# 8291          OK     WOODWARD     12  2014  2.252557e+08
#
# [8292 rows x 5 columns]

# %%
dfo_final.to_csv("Opioid_OK.csv")
dfo_final.to_parquet("Opioid_OK.gzip", compression="gzip")
