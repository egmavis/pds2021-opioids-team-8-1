# %%
import pandas as pd

# %%
def read_all_files():
    data_list = []
    for year in range(2003, 2016):
        df_temp = pd.read_csv(f"../00_source_data/US_VitalStatistics/Underlying Cause of Death, {year}.txt", delimiter="\t")
        data_list.append(df_temp)
    return pd.concat(data_list)

# %%
df = read_all_files()
df.sample(10)
# Out:
#      Notes                 County  County Code    Year  Year Code  \
# 1061   NaN     De Kalb County, IN      18033.0  2005.0     2005.0
# 3506   NaN     Andrews County, TX      48003.0  2007.0     2007.0
# 1983   NaN    Nicollet County, MN      27103.0  2009.0     2009.0
# 511    NaN   Middlesex County, CT       9007.0  2008.0     2008.0
# 2811   NaN     Watauga County, NC      37189.0  2008.0     2008.0
# 2823   NaN  Rutherford County, NC      37161.0  2010.0     2010.0
# 2153   NaN      Steele County, MN      27147.0  2015.0     2015.0
# 2876   NaN    Oklahoma County, OK      40109.0  2004.0     2004.0
# 1014   NaN      Wabash County, IL      17185.0  2004.0     2004.0
# 1471   NaN        Clay County, KY      21051.0  2009.0     2009.0
#
#                      Drug/Alcohol Induced Cause  \
# 1061  All other non-drug and non-alcohol causes
# 3506  All other non-drug and non-alcohol causes
# 1983  All other non-drug and non-alcohol causes
# 511   All other non-drug and non-alcohol causes
# 2811  All other non-drug and non-alcohol causes
# 2823  All other non-drug and non-alcohol causes
# 2153  All other non-drug and non-alcohol causes
# 2876              All other drug-induced causes
# 1014  All other non-drug and non-alcohol causes
# 1471  All other non-drug and non-alcohol causes
#
#      Drug/Alcohol Induced Cause Code  Deaths
# 1061                              O9   325.0
# 3506                              O9   124.0
# 1983                              O9   213.0
# 511                               O9  1376.0
# 2811                              O9   286.0
# 2823                              O9   803.0
# 2153                              O9     284
# 2876                              D9    10.0
# 1014                              O9   107.0
# 1471                              O9   237.0

# %%
## Remove abnormal values from data scripting
df = df.drop(df[df["County"].isnull()].index)

# %%
## Data Validity Check
assert not df["County"].isnull().any()
assert not df["Year"].isnull().any()
assert not df["Drug/Alcohol Induced Cause"].isnull().any()
assert not df["Deaths"].isnull().any()

# %%
# Since I only need data about Texas, subset data
# There are 254 counties in Texas
df_TX = df[df.County.str.contains("TX")].copy()
df_TX.sample(20)
# Out:
#      Notes                County  County Code    Year  Year Code  \
# 3793   NaN       Coke County, TX      48081.0  2013.0     2013.0
# 3656   NaN     Brooks County, TX      48047.0  2010.0     2010.0
# 3479   NaN  Childress County, TX      48075.0  2005.0     2005.0
# 3501   NaN       Hill County, TX      48217.0  2004.0     2004.0
# 3410   NaN       Clay County, TX      48077.0  2004.0     2004.0
# 3602   NaN     Harris County, TX      48201.0  2006.0     2006.0
# 3625   NaN    Tarrant County, TX      48439.0  2004.0     2004.0
# 3715   NaN    Cameron County, TX      48061.0  2011.0     2011.0
# 3987   NaN      Falls County, TX      48145.0  2015.0     2015.0
# 3434   NaN       Hale County, TX      48189.0  2003.0     2003.0
# 4043   NaN  Val Verde County, TX      48465.0  2013.0     2013.0
# 3776   NaN       Hill County, TX      48217.0  2010.0     2010.0
# 3878   NaN     Kinney County, TX      48271.0  2012.0     2012.0
# 3611   NaN  Galveston County, TX      48167.0  2007.0     2007.0
# 4025   NaN     Harris County, TX      48201.0  2015.0     2015.0
# 3874   NaN  Wilbarger County, TX      48487.0  2008.0     2008.0
# 3516   NaN     Castro County, TX      48069.0  2006.0     2006.0
# 3658   NaN  Jefferson County, TX      48245.0  2007.0     2007.0
# 3691   NaN   McLennan County, TX      48309.0  2007.0     2007.0
# 3995   NaN     Wilson County, TX      48493.0  2011.0     2011.0
#
#                              Drug/Alcohol Induced Cause  \
# 3793          All other non-drug and non-alcohol causes
# 3656          All other non-drug and non-alcohol causes
# 3479          All other non-drug and non-alcohol causes
# 3501          All other non-drug and non-alcohol causes
# 3410          All other non-drug and non-alcohol causes
# 3602  Drug poisonings (overdose) Unintentional (X40-...
# 3625                   All other alcohol-induced causes
# 3715          All other non-drug and non-alcohol causes
# 3987          All other non-drug and non-alcohol causes
# 3434          All other non-drug and non-alcohol causes
# 4043          All other non-drug and non-alcohol causes
# 3776          All other non-drug and non-alcohol causes
# 3878          All other non-drug and non-alcohol causes
# 3611  Drug poisonings (overdose) Unintentional (X40-...
# 4025                   All other alcohol-induced causes
# 3874          All other non-drug and non-alcohol causes
# 3516          All other non-drug and non-alcohol causes
# 3658  Drug poisonings (overdose) Unintentional (X40-...
# 3691  Drug poisonings (overdose) Unintentional (X40-...
# 3995          All other non-drug and non-alcohol causes
#
#      Drug/Alcohol Induced Cause Code  Deaths
# 3793                              O9    54.0
# 3656                              O9    84.0
# 3479                              O9    85.0
# 3501                              O9   396.0
# 3410                              O9    99.0
# 3602                              D1   348.0
# 3625                              A9    57.0
# 3715                              O9  2348.0
# 3987                              O9     177
# 3434                              O9   296.0
# 4043                              O9   354.0
# 3776                              O9   377.0
# 3878                              O9    31.0
# 3611                              D1    49.0
# 4025                              A9     232
# 3874                              O9   166.0
# 3516                              O9    54.0
# 3658                              D1    27.0
# 3691                              D1    12.0
# 3995                              O9   320.0

# %%
df_TX.to_csv("../20_intermediate_files/Underlying Cause of Death, 2003-2015, Texas.csv")
