# %%
import pandas as pd

# %%
def read_all_files():
    data_list = []
    for year in range(2003, 2016):
        df_temp = pd.read_csv(f"../00_source_data/US_VitalStatistics/Underlying Cause of Death, {year}.txt", delimiter="\t")
        data_list.append(df_temp)
    return pd.concat(data_list)

# %%
df = read_all_files()
df.sample(10)
# Out:
#      Notes                County  County Code    Year  Year Code  \
# 990    NaN    Madison County, ID      16065.0  2014.0     2014.0
# 4464   NaN      Hardy County, WV      54031.0  2014.0     2014.0
# 1389   NaN  Palo Alto County, IA      19147.0  2015.0     2015.0
# 1363   NaN   Sedgwick County, KS      20173.0  2006.0     2006.0
# 791    NaN     Monroe County, GA      13207.0  2005.0     2005.0
# 4043   NaN       Real County, TX      48385.0  2014.0     2014.0
# 2650   NaN     Nassau County, NY      36059.0  2011.0     2011.0
# 1568   NaN    Hancock County, KY      21091.0  2014.0     2014.0
# 2461   NaN    Douglas County, NV      32005.0  2012.0     2012.0
# 2856   NaN     Pierce County, ND      38069.0  2009.0     2009.0
#
#                          Drug/Alcohol Induced Cause  \
# 990       All other non-drug and non-alcohol causes
# 4464      All other non-drug and non-alcohol causes
# 1389      All other non-drug and non-alcohol causes
# 1363               All other alcohol-induced causes
# 791       All other non-drug and non-alcohol causes
# 4043      All other non-drug and non-alcohol causes
# 2650  Alcohol poisonings (overdose) (X45, X65, Y15)
# 1568      All other non-drug and non-alcohol causes
# 2461      All other non-drug and non-alcohol causes
# 2856      All other non-drug and non-alcohol causes
#
#      Drug/Alcohol Induced Cause Code Deaths
# 990                               O9  123.0
# 4464                              O9  156.0
# 1389                              O9    126
# 1363                              A9   38.0
# 791                               O9  214.0
# 4043                              O9   54.0
# 2650                              A1   15.0
# 1568                              O9   74.0
# 2461                              O9  391.0
# 2856                              O9   59.0

# %%
# Remove abnormal values from data scripting
df = df.drop(df[df["County"].isnull()].index)

# %%
# Basic Data Validity Check
assert not df["County"].isnull().any()
assert not df["Year"].isnull().any()
assert not df["Drug/Alcohol Induced Cause"].isnull().any()
assert not df["Deaths"].isnull().any()
assert not (df["Deaths"] == 0).any()

# %%
def check_state(state_str):
    target_list = ["TX", "FL"]
    state = state_str.split(", ")[1]
    return 1 if state in target_list else 0

# %%
df["target_state"] = df.apply(lambda row: check_state(row.County), axis=1)
df_sub = df[df["target_state"] == 1]
df_sub.sample(10)
# Out:
#      Notes                    County  County Code    Year  Year Code  \
# 3558   NaN        Midland County, TX      48329.0  2004.0     2004.0
# 3534   NaN          Brown County, TX      48049.0  2007.0     2007.0
# 3468   NaN      Jefferson County, TX      48245.0  2003.0     2003.0
# 4032   NaN         Parker County, TX      48367.0  2014.0     2014.0
# 3681   NaN      Armstrong County, TX      48011.0  2011.0     2011.0
# 519    NaN        Broward County, FL      12011.0  2004.0     2004.0
# 4151   NaN  San Augustine County, TX      48405.0  2015.0     2015.0
# 3837   NaN        Tarrant County, TX      48439.0  2009.0     2009.0
# 3503   NaN           Hood County, TX      48221.0  2004.0     2004.0
# 678    NaN         Sumter County, FL      12119.0  2008.0     2008.0
#
#                              Drug/Alcohol Induced Cause  \
# 3558                   All other alcohol-induced causes
# 3534          All other non-drug and non-alcohol causes
# 3468  Drug poisonings (overdose) Unintentional (X40-...
# 4032          All other non-drug and non-alcohol causes
# 3681          All other non-drug and non-alcohol causes
# 519                       All other drug-induced causes
# 4151          All other non-drug and non-alcohol causes
# 3837      Alcohol poisonings (overdose) (X45, X65, Y15)
# 3503          All other non-drug and non-alcohol causes
# 678           All other non-drug and non-alcohol causes
#
#      Drug/Alcohol Induced Cause Code  Deaths  target_state
# 3558                              A9    11.0             1
# 3534                              O9   464.0             1
# 3468                              D1    16.0             1
# 4032                              O9  1017.0             1
# 3681                              O9    25.0             1
# 519                               D9    15.0             1
# 4151                              O9     128             1
# 3837                              A1    10.0             1
# 3503                              O9   517.0             1
# 678                               O9   999.0             1

# %%
# Data validity check: County Check

# Since TX has 254 counties, the County column should have all 254 unique values
df_TX = df_sub[df_sub.County.str.contains("TX")].copy()

# Assertion failed, there are only 251 counties, commented out
# assert df_TX["County"].nunique() == 254

# %%
# Find missing counties
real_counties = []
with open ("../00_source_data/texas_counties") as file:
    for line in file:
        real_counties.append(line.replace("\n", ""))

dataset_counties = []
for county in df_TX["County"].unique():
    dataset_counties.append(county.split(",")[0])

list(set(real_counties) - set(dataset_counties))
# Out:
# ['King County', 'Loving County', 'Kenedy County']

# %%
assert df[(df.County.str.contains("King County")) & df.County.str.contains("TX")].empty
assert df[(df.County.str.contains("Loving County")) & df.County.str.contains("TX")].empty
assert df[(df.County.str.contains("Kenedy County")) & df.County.str.contains("TX")].empty

# It seems that these three counties had no overdose deaths. So we do not need to perform county check on all states anymore.

# %%
df_sub.to_csv("../20_intermediate_files/Underlying Cause of Death, 2003-2015.csv")
df_sub.to_parquet("../20_intermediate_files/Underlying Cause of Death, 2003-2015.gzip", compression="gzip")
