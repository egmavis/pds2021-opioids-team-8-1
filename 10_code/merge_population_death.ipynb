# %% [markdown]
# **Importing files and looking at structures**

# %%
import pandas as pd
import numpy as np

# %%
overall_pop = pd.read_csv('~/720/pds2021-opioids-team-8-1/20_intermediate_files/Population_2000-2019.csv')

# %%
overall_cause_of_death = pd.read_csv('~/720/pds2021-opioids-team-8-1/20_intermediate_files/Underlying Cause of Death, 2003-2015.csv')

# %%
overall_cause_of_death.sample(15)
# Out:
#        Unnamed: 0  Notes                County  County Code    Year  \
# 8374         3829    NaN    Houston County, TX      48225.0  2011.0
# 3414         3508    NaN   Caldwell County, TX      48055.0  2006.0
# 8639         4421    NaN       Iron County, WI      55051.0  2011.0
# 9245         3726    NaN   Brazoria County, TX      48039.0  2012.0
# 4466         3618    NaN       Gray County, TX      48179.0  2007.0
# 11765         528    NaN      Ouray County, CO       8091.0  2015.0
# 11784         547    NaN       Weld County, CO       8123.0  2015.0
# 11938        1727    NaN  Jefferson Parish, LA      22051.0  2015.0
# 9769          466    NaN     Elbert County, CO       8039.0  2013.0
# 3800         4178    NaN    Kenosha County, WI      55059.0  2006.0
# 5239         3046    NaN      Grant County, OK      40053.0  2008.0
# 3085         1362    NaN   Sedgwick County, KS      20173.0  2006.0
# 4748         4218    NaN   Kewaunee County, WI      55061.0  2007.0
# 5002         1393    NaN      Riley County, KS      20161.0  2008.0
# 4214         2022    NaN   Lawrence County, MS      28077.0  2007.0
#
#        Year Code                         Drug/Alcohol Induced Cause  \
# 8374      2011.0          All other non-drug and non-alcohol causes
# 3414      2006.0          All other non-drug and non-alcohol causes
# 8639      2011.0          All other non-drug and non-alcohol causes
# 9245      2012.0                   All other alcohol-induced causes
# 4466      2007.0          All other non-drug and non-alcohol causes
# 11765     2015.0          All other non-drug and non-alcohol causes
# 11784     2015.0                   All other alcohol-induced causes
# 11938     2015.0                   All other alcohol-induced causes
# 9769      2013.0          All other non-drug and non-alcohol causes
# 3800      2006.0  Drug poisonings (overdose) Unintentional (X40-...
# 5239      2008.0          All other non-drug and non-alcohol causes
# 3085      2006.0  Drug poisonings (overdose) Unintentional (X40-...
# 4748      2007.0          All other non-drug and non-alcohol causes
# 5002      2008.0          All other non-drug and non-alcohol causes
# 4214      2007.0          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code  Deaths  target_state
# 8374                               O9   266.0             1
# 3414                               O9   287.0             1
# 8639                               O9    74.0             1
# 9245                               A9    10.0             1
# 4466                               O9   251.0             1
# 11765                              O9    20.0             1
# 11784                              A9    39.0             1
# 11938                              A9    55.0             1
# 9769                               O9   115.0             1
# 3800                               D1    24.0             1
# 5239                               O9    68.0             1
# 3085                               D1    60.0             1
# 4748                               O9   195.0             1
# 5002                               O9   313.0             1
# 4214                               O9   140.0             1

# %%
overall_pop.sample(15)
# Out:
#      Unnamed: 0             County    2000      2001      2002      2003  \
# 77           77     Bastrop County   58234   61106.0   63508.0   65825.0
# 262         262     Refugio County    7827    7765.0    7665.0    7563.0
# 469         469       Kiowa County    1610    1550.0    1519.0    1501.0
# 302         302      Walker County   61768   62444.0   62216.0   63609.0
# 112         112       Comal County   78583   80630.0   82797.0   84837.0
# 741         741       Scott County    5100    5110.0    4960.0    4865.0
# 381         381   Bienville Parish   15717   15400.0   15279.0   15077.0
# 142         142      Fisher County    4340    4257.0    4242.0    4191.0
# 622         622  Montgomery County   12115   12042.0   11829.0   11647.0
# 383         383       Caddo Parish  250990  249815.0  248753.0  248346.0
# 230         230      Menard County    2342    2321.0    2340.0    2311.0
# 761         761       Adair County   21031   21101.0   21271.0   21445.0
# 318         318       Young County   17846   17659.0   17665.0   17892.0
# 427         427      Tensas Parish    6535    6334.0    6150.0    5941.0
# 517         517     Douglas County   43365   43529.0   43593.0   43790.0
#
#          2004      2005      2006      2007  ...      2011      2012  \
# 77    67122.0   68233.0   69720.0   71348.0  ...   75055.0   74749.0
# 262    7630.0    7601.0    7548.0    7414.0  ...    7321.0    7256.0
# 469    1457.0    1467.0    1456.0    1410.0  ...    1431.0    1409.0
# 302   64551.0   65676.0   65591.0   65517.0  ...   68409.0   68609.0
# 112   88119.0   91018.0   95637.0   99540.0  ...  112113.0  114873.0
# 741    4713.0    4771.0    4738.0    4707.0  ...    4889.0    4853.0
# 381   15017.0   14852.0   14773.0   14699.0  ...   14261.0   14192.0
# 142    4118.0    4135.0    4098.0    4080.0  ...    3947.0    3838.0
# 622   11507.0   11474.0   11453.0   11297.0  ...   10775.0   10604.0
# 383  249157.0  249593.0  252740.0  251760.0  ...  256967.0  257252.0
# 230    2265.0    2212.0    2199.0    2176.0  ...    2214.0    2204.0
# 761   21589.0   21887.0   22215.0   22345.0  ...   22667.0   22468.0
# 318   17921.0   17801.0   18227.0   18135.0  ...   18355.0   18278.0
# 427    5785.0    5700.0    5719.0    5513.0  ...    5092.0    4999.0
# 517   43833.0   43872.0   43815.0   43710.0  ...   43958.0   43751.0
#
#          2013      2014      2015      2016      2017      2018      2019  \
# 77    75814.0   77737.0   80115.0   82591.0   84585.0   86595.0   88723.0
# 262    7279.0    7362.0    7326.0    7272.0    7180.0    7000.0    6948.0
# 469    1392.0    1380.0    1384.0    1342.0    1365.0    1379.0    1406.0
# 302   69404.0   70076.0   70836.0   71845.0   72816.0   73136.0   72971.0
# 112  118627.0  123214.0  128795.0  134343.0  140721.0  148141.0  156209.0
# 741    4906.0    4966.0    4948.0    4979.0    4928.0    4909.0    4823.0
# 381   13961.0   13782.0   13823.0   13780.0   13631.0   13343.0   13241.0
# 142    3859.0    3874.0    3877.0    3877.0    3874.0    3821.0    3830.0
# 622   10579.0   10363.0   10195.0   10235.0   10143.0    9994.0    9775.0
# 383  255127.0  252605.0  251345.0  248837.0  245935.0  242833.0  240204.0
# 230    2137.0    2128.0    2134.0    2091.0    2110.0    2120.0    2138.0
# 761   22460.0   22384.0   22259.0   22305.0   22119.0   22224.0   22194.0
# 318   18354.0   18274.0   18163.0   18098.0   17922.0   17986.0   18010.0
# 427    4933.0    4853.0    4772.0    4656.0    4574.0    4470.0    4334.0
# 517   43760.0   43643.0   43495.0   43359.0   43328.0   43143.0   43150.0
#
#      _merge
# 77     both
# 262    both
# 469    both
# 302    both
# 112    both
# 741    both
# 381    both
# 142    both
# 622    both
# 383    both
# 230    both
# 761    both
# 318    both
# 427    both
# 517    both
#
# [15 rows x 24 columns]

# %%
overall_pop.columns
# Out:
# Index(['Unnamed: 0', 'County', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', 'State', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '_merge'],
#       dtype='object')

# %% [markdown]
# **Now we need to get both datasets into a form where we can merge on state-county-year**

# %% [markdown]
# **It looks like the cause of death data has *state* included in the *county* column, but the population has seperate *county* and *state* columns. So we need to separate the county-state information in the cause of death dataset**

# %%
# extract state information from county column in the cause of death data

overall_cause_of_death['State'] = ''
overall_cause_of_death.State = [overall_cause_of_death.County[i][-2:] for i in range(len(overall_cause_of_death.County))]

# %%
overall_cause_of_death.sample(10)
# Out:
#        Unnamed: 0  Notes                County  County Code    Year  \
# 1016          401    NaN   Cheyenne County, CO       8017.0  2004.0
# 10758         470    NaN    El Paso County, CO       8041.0  2014.0
# 9210         3206    NaN      Texas County, OK      40139.0  2012.0
# 3498         3592    NaN      Gregg County, TX      48183.0  2006.0
# 157          1244    NaN    Greeley County, KS      20071.0  2003.0
# 5898         1343    NaN     Cowley County, KS      20035.0  2009.0
# 4237         2045    NaN     Rankin County, MS      28121.0  2007.0
# 5418         3683    NaN      Gregg County, TX      48183.0  2008.0
# 3188         1607    NaN  Vermilion Parish, LA      22113.0  2006.0
# 10896        1481    NaN       Rice County, KS      20159.0  2014.0
#
#        Year Code                         Drug/Alcohol Induced Cause  \
# 1016      2004.0          All other non-drug and non-alcohol causes
# 10758     2014.0          All other non-drug and non-alcohol causes
# 9210      2012.0          All other non-drug and non-alcohol causes
# 3498      2006.0          All other non-drug and non-alcohol causes
# 157       2003.0          All other non-drug and non-alcohol causes
# 5898      2009.0          All other non-drug and non-alcohol causes
# 4237      2007.0  Drug poisonings (overdose) Unintentional (X40-...
# 5418      2008.0          All other non-drug and non-alcohol causes
# 3188      2006.0          All other non-drug and non-alcohol causes
# 10896     2014.0          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code  Deaths  target_state State
# 1016                               O9    13.0             1    CO
# 10758                              O9  3824.0             1    CO
# 9210                               O9   134.0             1    OK
# 3498                               O9  1154.0             1    TX
# 157                                O9    19.0             1    KS
# 5898                               O9   411.0             1    KS
# 4237                               D1    16.0             1    MS
# 5418                               O9  1223.0             1    TX
# 3188                               O9   512.0             1    LA
# 10896                              O9   129.0             1    KS

# %%
# extract county information from county column in the cause of death data

overall_cause_of_death['temp_County'] = ''
overall_cause_of_death['temp_County']= [overall_cause_of_death.County[i][:-4] for i in range(len(overall_cause_of_death.County))]

# %%
overall_cause_of_death.sample(10)
# Out:
#        Unnamed: 0  Notes                  County  County Code    Year  \
# 11619        4578    NaN    Outagamie County, WI      55087.0  2014.0
# 4211         2019    NaN    Lafayette County, MS      28071.0  2007.0
# 12336        4032    NaN         Hays County, TX      48209.0  2015.0
# 2220         1574    NaN     Richland Parish, LA      22083.0  2005.0
# 5330         3595    NaN        Brown County, TX      48049.0  2008.0
# 7228         3139    NaN        Tulsa County, OK      40143.0  2010.0
# 737          3564    NaN  Shackelford County, TX      48417.0  2003.0
# 10019        1710    NaN   Tangipahoa Parish, LA      22105.0  2013.0
# 572          3399    NaN       Donley County, TX      48129.0  2003.0
# 4796          121    NaN      Cochise County, AZ       4003.0  2008.0
#
#        Year Code                         Drug/Alcohol Induced Cause  \
# 11619     2014.0  Drug poisonings (overdose) Unintentional (X40-...
# 4211      2007.0          All other non-drug and non-alcohol causes
# 12336     2015.0          All other non-drug and non-alcohol causes
# 2220      2005.0          All other non-drug and non-alcohol causes
# 5330      2008.0          All other non-drug and non-alcohol causes
# 7228      2010.0       Drug poisonings (overdose) Suicide (X60-X64)
# 737       2003.0          All other non-drug and non-alcohol causes
# 10019     2013.0          All other non-drug and non-alcohol causes
# 572       2003.0          All other non-drug and non-alcohol causes
# 4796      2008.0                   All other alcohol-induced causes
#
#       Drug/Alcohol Induced Cause Code  Deaths  target_state State  \
# 11619                              D1    13.0             1    WI
# 4211                               O9   321.0             1    MS
# 12336                              O9   972.0             1    TX
# 2220                               O9   265.0             1    LA
# 5330                               O9   505.0             1    TX
# 7228                               D2    16.0             1    OK
# 737                                O9    45.0             1    TX
# 10019                              O9  1185.0             1    LA
# 572                                O9    38.0             1    TX
# 4796                               A9    11.0             1    AZ
#
#               temp_County
# 11619    Outagamie County
# 4211     Lafayette County
# 12336         Hays County
# 2220      Richland Parish
# 5330         Brown County
# 7228         Tulsa County
# 737    Shackelford County
# 10019   Tangipahoa Parish
# 572         Donley County
# 4796       Cochise County

# %% [markdown]
# **We now have seperate *state* and *county* columns in the cause of death data set, so we drop the County column (and other unnecessary columns for merging) and rename the temp_County column**

# %%
overall_cause_of_death.drop(labels=['County', 'Unnamed: 0', 'Notes', 'Year Code'], axis=1, inplace=True)

# %%
overall_cause_of_death.rename({'temp_County':'County'}, axis=1, inplace=True)

# %%
overall_cause_of_death.sample(10)
# Out:
#        County Code    Year                         Drug/Alcohol Induced Cause  \
# 1003        8003.0  2004.0          All other non-drug and non-alcohol causes
# 10418      48299.0  2013.0          All other non-drug and non-alcohol causes
# 7285       48079.0  2010.0          All other non-drug and non-alcohol causes
# 272        22055.0  2003.0  Drug poisonings (overdose) Unintentional (X40-...
# 3706       53011.0  2006.0                   All other alcohol-induced causes
# 12304      48165.0  2015.0          All other non-drug and non-alcohol causes
# 8183       40105.0  2011.0          All other non-drug and non-alcohol causes
# 9493       48433.0  2012.0          All other non-drug and non-alcohol causes
# 670        48303.0  2003.0          All other non-drug and non-alcohol causes
# 6225       40097.0  2009.0          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code  Deaths  target_state State  \
# 1003                               O9    81.0             1    CO
# 10418                              O9   278.0             1    TX
# 7285                               O9    32.0             1    TX
# 272                                D1    24.0             1    LA
# 3706                               A9    42.0             1    WA
# 12304                              O9   125.0             1    TX
# 8183                               O9   126.0             1    OK
# 9493                               O9    28.0             1    TX
# 670                                O9  2022.0             1    TX
# 6225                               O9   447.0             1    OK
#
#                  County
# 1003     Alamosa County
# 10418      Llano County
# 7285     Cochran County
# 272    Lafayette Parish
# 3706       Clark County
# 12304     Gaines County
# 8183      Nowata County
# 9493   Stonewall County
# 670      Lubbock County
# 6225       Mayes County

# %% [markdown]
# **Now must melt down year headers from the population data set into single column of observations to match the cause of death data set**

# %%
# first drop unnecessary columns "Unnamed: 0" and "_merge"
overall_pop.drop(labels=['Unnamed: 0', '_merge'], axis=1, inplace=True)

# %%
overall_pop.head()
# Out:
#             County    2000      2001      2002      2003      2004      2005  \
# 0   Alachua County  218611  221718.0  224614.0  227022.0  229867.0  233756.0
# 1     Baker County   22374   22620.0   23298.0   23555.0   24142.0   24832.0
# 2       Bay County  148393  150207.0  152741.0  155044.0  158804.0  162917.0
# 3  Bradford County   26064   26083.0   26306.0   27035.0   27703.0   28098.0
# 4   Brevard County  477819  486429.0  495425.0  504847.0  518722.0  529907.0
#
#        2006      2007      2008  ...    2010      2011      2012      2013  \
# 0  239506.0  242685.0  244888.0  ...  247614  249834.0  251520.0  252475.0
# 1   25571.0   26212.0   26725.0  ...   27066   27049.0   27053.0   27009.0
# 2  165644.0  165345.0  166267.0  ...  169206  169555.0  171757.0  174596.0
# 3   28506.0   28825.0   28961.0  ...   28536   28431.0   27051.0   26802.0
# 4  535138.0  539719.0  542378.0  ...  543965  544359.0  546966.0  550255.0
#
#        2014      2015      2016      2017      2018      2019
# 0  255456.0  259052.0  263959.0  266309.0  268851.0  269043.0
# 1   27122.0   27355.0   27884.0   28254.0   28353.0   29210.0
# 2  178289.0  181488.0  183634.0  184736.0  186240.0  174705.0
# 3   26552.0   26748.0   26740.0   27142.0   27752.0   28201.0
# 4  555548.0  565746.0  576874.0  587769.0  595203.0  601942.0
#
# [5 rows x 22 columns]

# %%
overall_pop_melted = overall_pop.melt(id_vars=['County', 'State'], value_vars=overall_pop.filter(like='20').columns.tolist(), var_name='Year', value_name='Population')

# %%
overall_pop_melted.head()
# Out:
#             County State  Year  Population
# 0   Alachua County    Fl  2000    218611.0
# 1     Baker County    Fl  2000     22374.0
# 2       Bay County    Fl  2000    148393.0
# 3  Bradford County    Fl  2000     26064.0
# 4   Brevard County    Fl  2000    477819.0

# %%
overall_cause_of_death.head(10)
# Out:
#    County Code    Year                         Drug/Alcohol Induced Cause  \
# 0       4001.0  2003.0                   All other alcohol-induced causes
# 1       4001.0  2003.0          All other non-drug and non-alcohol causes
# 2       4003.0  2003.0  Drug poisonings (overdose) Unintentional (X40-...
# 3       4003.0  2003.0                   All other alcohol-induced causes
# 4       4003.0  2003.0          All other non-drug and non-alcohol causes
# 5       4005.0  2003.0  Drug poisonings (overdose) Unintentional (X40-...
# 6       4005.0  2003.0                   All other alcohol-induced causes
# 7       4005.0  2003.0          All other non-drug and non-alcohol causes
# 8       4007.0  2003.0          All other non-drug and non-alcohol causes
# 9       4009.0  2003.0          All other non-drug and non-alcohol causes
#
#   Drug/Alcohol Induced Cause Code  Deaths  target_state State           County
# 0                              A9    22.0             1    AZ    Apache County
# 1                              O9   464.0             1    AZ    Apache County
# 2                              D1    11.0             1    AZ   Cochise County
# 3                              A9    14.0             1    AZ   Cochise County
# 4                              O9  1109.0             1    AZ   Cochise County
# 5                              D1    11.0             1    AZ  Coconino County
# 6                              A9    27.0             1    AZ  Coconino County
# 7                              O9   595.0             1    AZ  Coconino County
# 8                              O9   625.0             1    AZ      Gila County
# 9                              O9   255.0             1    AZ    Graham County

# %%
print(overall_cause_of_death.dtypes)
print(overall_pop_melted.dtypes)
# Out:
# County Code                        float64
# Year                               float64
# Drug/Alcohol Induced Cause          object
# Drug/Alcohol Induced Cause Code     object
# Deaths                             float64
# target_state                         int64
# State                               object
# County                              object
# dtype: object
# County         object
# State          object
# Year           object
# Population    float64
# dtype: object

# %% [markdown]
# **Change types of columns we want to merge so they match**

# %%
overall_pop_melted.Year = overall_pop_melted.Year.astype(np.float64)

# %%
overall_pop_melted.dtypes
# Out:
# County         object
# State          object
# Year          float64
# Population    float64
# dtype: object

# %% [markdown]
# **Cause of death data is now in a format to merge successfully with the population dataset**

# %%
merged = overall_cause_of_death.merge(overall_pop_melted, on=['Year', 'State', 'County'], validate='m:1', indicator=True)

# %%
assert merged[merged['_merge'] != 'both'].empty

# %%
merged.isnull().sum().sum()
# Out:
# 0

# %%
assert [not merged[col].isnull().any() for col in merged.columns]
